# %%
import json
import numpy as np
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
from sentence_transformers import SentenceTransformer

# %%
nlp = spacy.load("en_core_web_sm")
SBertModel = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2305.80it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
cleanText = set(json.load(open("templates/symptomNormalizations.json", "r")).values())
cleanText
# Out:
# {'balance_problems',
#  'cerumen_impaction',
#  'dizziness',
#  'dizziness_with_nausea',
#  'ear_fullness',
#  'ear_itching',
#  'ear_pain',
#  'ear_redness',
#  'ear_swelling',
#  'facial_numbness',
#  'facial_weakness',
#  'fatigue',
#  'fever',
#  'fluid_discharge',
#  'general_illness',
#  'hearing_loss',
#  'hyperacusis',
#  'muffled_hearing',
#  'popping_sound',
#  'pulsatile_tinnitus',
#  'tinnitus',
#  'vertigo'}

# %%
def generateSbertFeatures(cleanText):
    return SBertModel.encode(list(cleanText))

# %%
SBert = generateSbertFeatures(cleanText)
SBert.shape
# Out:
# (22, 384)
